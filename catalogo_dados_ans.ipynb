# %%
import pandas as pd
import numpy as np
import requests as re
import utils as ut

from io import BytesIO, StringIO
from zipfile import ZipFile

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

IGR - Índice Geral de Reclamações:

O Índice Geral de Reclamações (IGR) é uma métrica calculada pela ANS com base nas reclamações registradas por consumidores e que foram processadas via Notificação de Intermediação Preliminar (NIP).

Tal indicador foi desenvolvido com o objetivo de dar maior transparência às reivindicações registradas por consumidores junto aos canais de atendimento da ANS, 
funcionando como um termômetro da satisfação dos serviços prestados pelas operadoras de planos de saúde. 

Ele apresenta uma relação inversamente proporcional à satisfação dos beneficiários, vale dizer, que quanto menor o valor do IGR, maior é a satisfação dos beneficiários com a(s) Operadora(s).
_____________________________________________________________________________________________________________________________________________________________________________________________________

Fluxo:

1. Gera o arquivo com a função ut.baixar_extrair_mesclar()
2. Lê o arquivo com a função read_csv() fornecida na saída da função.

"""
igr_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv'
ut.baixar_extrair_mesclar(igr_url)

#df_origem_igr = pl.read_csv(r"c:\GIT\DadosANS\processamentos\IGR_20260325_205249\ingestao\downloads\IGR.csv")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : inicialização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Início do processamento
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_origem
# 🧭 ETAPA : Origem detectada: arquivo_tabular
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\IGR_20260325_213352
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🌐 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Baixando arquivo único
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Arquivo tabular ingerido com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\IGR_20260325_213352\ingestao\downloads
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: mesclagem incremental
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\IGR_20260325_213352
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ℹ️ FASE : saída
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem não executada: apenas um arquivo compatível foi ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\IGR_20260325_213352\ingestao\downloads
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📌 COMANDOS PRONTOS PARA LEITURA DOS ARQUIVOS NO POLARS
# Cole os comandos abaixo no notebook:
#
# import polars as pl
#
# # Arquivos originais baixados/gerados
# df_origem_igr = pl.read_csv(r"c:\GIT\DadosANS\processamentos\IGR_20260325_213352\ingestao\downloads\IGR.csv")
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🏁 FASE : finalização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Processamento concluído com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\IGR_20260325_213352
# 📄 ARQUIVO: resultado final
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# {'conteudo_zip': None,
#  'pasta_execucao': 'c:\\GIT\\DadosANS\\processamentos\\IGR_20260325_213352',
#  'pasta_ingestao': 'c:\\GIT\\DadosANS\\processamentos\\IGR_20260325_213352\\ingestao',
#  'manifesto_arquivos': 'c:\\GIT\\DadosANS\\processamentos\\IGR_20260325_213352\\manifesto_arquivos.csv',
#  'arquivos_lidos': ['IGR.csv'],
#  'arquivos_ignorados': [],
#  'erros': [],
#  'df_unificado': None}

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

VMFE - Valor Comercial da Mensalidade por Faixa Etária

O conjunto de dados abertos "Valor Comercial da Mensalidade por faixa etária" se refere aos dados informados nas Notas Técnicas homologadas junto à ANS em conformidade com o Anexo II-B, 
da IN/DIPRO Nº 8, de 27 de dezembro de 2002.

_____________________________________________________________________________________________________________________________________________________________________________________________________

Fluxo:

1. Gera o arquivo com a função ut.baixar_extrair_mesclar()
2. Lê o arquivo com a função read_csv() fornecida na saída da função.

O arquivo final (mesclado) contém 574MB

"""

vmfe_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/nota_tecnica_ntrp_vcm_faixa_etaria/nota_tecnica_vcm_faixa_etaria.zip'
ut.baixar_extrair_mesclar(vmfe_url)

#df_mescla_etaria = pl.read_csv(r"c:\GIT\DadosANS\mescla_ETARIA.csv")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : inicialização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Início do processamento
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/nota_tecnica_ntrp_vcm_faixa_etaria/nota_tecnica_vcm_faixa_etaria.zip
# 📄 ARQUIVO: nota_tecnica_vcm_faixa_etaria.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_origem
# 🧭 ETAPA : Origem detectada: arquivo_zip
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/nota_tecnica_ntrp_vcm_faixa_etaria/nota_tecnica_vcm_faixa_etaria.zip
# 📄 ARQUIVO: nota_tecnica_vcm_faixa_etaria.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: https://dadosabertos.ans.gov.br/FTP/PDA/nota_tecnica_ntrp_vcm_faixa_etaria/nota_tecnica_vcm_faixa_etaria.zip
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🌐 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Baixando arquivo único
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/nota_tecnica_ntrp_vcm_faixa_etaria/nota_tecnica_vcm_faixa_etaria.zip
# 📄 ARQUIVO: nota_tecnica_vcm_faixa_etaria.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: nota_tecnica_vcm_faixa_etaria.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2004.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/23 (0.0%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2005.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/23 (4.3%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2006.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/23 (8.7%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2007.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/23 (13.0%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2008.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 4/23 (17.4%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2009.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 5/23 (21.7%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2010.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 6/23 (26.1%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2011.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 7/23 (30.4%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2012.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 8/23 (34.8%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2013.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 9/23 (39.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2014.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 10/23 (43.5%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2015.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 11/23 (47.8%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2016.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 12/23 (52.2%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2017.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 13/23 (56.5%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2018.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 14/23 (60.9%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2019.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 15/23 (65.2%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2020.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 16/23 (69.6%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2021.csv
# 📊 STATUS : [███████████████████░░░░░░░] 17/23 (73.9%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2022.csv
# 📊 STATUS : [████████████████████░░░░░░] 18/23 (78.3%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2023.csv
# 📊 STATUS : [█████████████████████░░░░░] 19/23 (82.6%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2024.csv
# 📊 STATUS : [███████████████████████░░░] 20/23 (87.0%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2025.csv
# 📊 STATUS : [████████████████████████░░] 21/23 (91.3%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2026.csv
# 📊 STATUS : [█████████████████████████░] 22/23 (95.7%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : ZIP baixado e extraído recursivamente para disco
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\downloads\nota_tecnica_vcm_faixa_etaria.zip
# 📄 ARQUIVO: nota_tecnica_vcm_faixa_etaria.zip
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: mesclagem incremental
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403
# 📄 ARQUIVO: 23 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/23 (0.0%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2004.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/23 (0.0%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2004.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/23 (4.3%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2005.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/23 (4.3%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/23 (8.7%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2006.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/23 (8.7%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/23 (13.0%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2007.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/23 (13.0%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 4/23 (17.4%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2008.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 4/23 (17.4%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 5/23 (21.7%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2009.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 5/23 (21.7%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 6/23 (26.1%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2010.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 6/23 (26.1%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 7/23 (30.4%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2011.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 7/23 (30.4%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 8/23 (34.8%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2012.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 8/23 (34.8%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 9/23 (39.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2013.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 9/23 (39.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 10/23 (43.5%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2014.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 10/23 (43.5%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 11/23 (47.8%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2015.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 11/23 (47.8%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 12/23 (52.2%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2016.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 12/23 (52.2%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 13/23 (56.5%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2017.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 13/23 (56.5%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 14/23 (60.9%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2018.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 14/23 (60.9%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 15/23 (65.2%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2019.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 15/23 (65.2%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 16/23 (69.6%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2020.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 16/23 (69.6%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███████████████████░░░░░░░] 17/23 (73.9%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2021.csv
# 📊 STATUS : [███████████████████░░░░░░░] 17/23 (73.9%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [████████████████████░░░░░░] 18/23 (78.3%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2022.csv
# 📊 STATUS : [████████████████████░░░░░░] 18/23 (78.3%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [█████████████████████░░░░░] 19/23 (82.6%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2023.csv
# 📊 STATUS : [█████████████████████░░░░░] 19/23 (82.6%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [███████████████████████░░░] 20/23 (87.0%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2024.csv
# 📊 STATUS : [███████████████████████░░░] 20/23 (87.0%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [████████████████████████░░] 21/23 (91.3%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2025.csv
# 📊 STATUS : [████████████████████████░░] 21/23 (91.3%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [█████████████████████████░] 22/23 (95.7%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria
# 📄 ARQUIVO: NOTA_TECNICA_VCM_FAIXA_ETARIA_2026.csv
# 📊 STATUS : [█████████████████████████░] 22/23 (95.7%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo ETARIA
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_ETARIA.csv
# 📊 STATUS : [██████████████████████████] 23/23 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 💾 FASE : saída
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Arquivos CSV por grupo gerados com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: 1 grupo(s)
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📌 COMANDOS PRONTOS PARA LEITURA DOS ARQUIVOS NO POLARS
# Cole os comandos abaixo no notebook:
#
# import polars as pl
#
# # Arquivos originais baixados/gerados
# df_origem_nota_tecnica_vcm_faixa_etaria_2004 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2004.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2005 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2005.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2006 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2006.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2007 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2007.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2008 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2008.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2009 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2009.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2010 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2010.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2011 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2011.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2012 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2012.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2013 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2013.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2014 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2014.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2015 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2015.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2016 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2016.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2017 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2017.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2018 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2018.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2019 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2019.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2020 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2020.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2021 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2021.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2022 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2022.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2023 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2023.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2024 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2024.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2025 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2025.csv")
# df_origem_nota_tecnica_vcm_faixa_etaria_2026 = pl.read_csv(r"c:\GIT\DadosANS\processamentos\VMFE_20260325_213403\ingestao\extraidos\nota_tecnica_vcm_faixa_etaria\NOTA_TECNICA_VCM_FAIXA_ETARIA_2026.csv")
#
# # Arquivos mesclados por grupo
# df_mescla_etaria = pl.read_csv(r"c:\GIT\DadosANS\mescla_ETARIA.csv")
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🏁 FASE : finalização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Processamento concluído com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\VMFE_20260325_213403
# 📄 ARQUIVO: resultado final
# 📊 STATUS : [██████████████████████████] 23/23 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

TR - Taxa de Resolutividade:

A Taxa de Resolutividade (TR) é uma métrica calculada pela ANS com base nas reclamações registradas por consumidores e que foram processadas via Notificação de Intermediação Preliminar (NIP), 
que é considerado um método extrajudicial de resolução de conflitos. A TR mede a capacidade de resolução das demandas objeto de NIP, sem a necessidade de abertura de processo administrativo. 

Assim sendo, um percentual elevado de finalização de demandas no âmbito da NIP indica que a Operadora tem maior capacidade de equacionar o indício de infração narrado pelo consumidor.
_____________________________________________________________________________________________________________________________________________________________________________________________________

Fluxo:

1. Gera o arquivo com a função ut.baixar_extrair_mesclar()
2. Lê o arquivo com a função read_csv() fornecida na saída da função.

"""

tr_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/taxa_de_resolutividade/pda-048-taxa_de_resolutividade.csv'
ut.baixar_extrair_mesclar(tr_url)

#df_origem_pda_048_taxa_de_resolutividade = pl.read_csv(r"c:\GIT\DadosANS\processamentos\TR_20260325_213907\ingestao\downloads\pda-048-taxa_de_resolutividade.csv")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : inicialização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Início do processamento
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/taxa_de_resolutividade/pda-048-taxa_de_resolutividade.csv
# 📄 ARQUIVO: pda-048-taxa_de_resolutividade.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_origem
# 🧭 ETAPA : Origem detectada: arquivo_tabular
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/taxa_de_resolutividade/pda-048-taxa_de_resolutividade.csv
# 📄 ARQUIVO: pda-048-taxa_de_resolutividade.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: https://dadosabertos.ans.gov.br/FTP/PDA/taxa_de_resolutividade/pda-048-taxa_de_resolutividade.csv
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\TR_20260325_213907
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🌐 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Baixando arquivo único
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/taxa_de_resolutividade/pda-048-taxa_de_resolutividade.csv
# 📄 ARQUIVO: pda-048-taxa_de_resolutividade.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Arquivo tabular ingerido com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\TR_20260325_213907\ingestao\downloads
# 📄 ARQUIVO: pda-048-taxa_de_resolutividade.csv
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: mesclagem incremental
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\TR_20260325_213907
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ℹ️ FASE : saída
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem não executada: apenas um arquivo compatível foi ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\TR_20260325_213907\ingestao\downloads
# 📄 ARQUIVO: pda-048-taxa_de_resolutividade.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📌 COMANDOS PRONTOS PARA LEITURA DOS ARQUIVOS NO POLARS
# Cole os comandos abaixo no notebook:
#
# import polars as pl
#
# # Arquivos originais baixados/gerados
# df_origem_pda_048_taxa_de_resolutividade = pl.read_csv(r"c:\GIT\DadosANS\processamentos\TR_20260325_213907\ingestao\downloads\pda-048-taxa_de_resolutividade.csv")
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🏁 FASE : finalização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Processamento concluído com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\TR_20260325_213907
# 📄 ARQUIVO: resultado final
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# {'conteudo_zip': None,
#  'pasta_execucao': 'c:\\GIT\\DadosANS\\processamentos\\TR_20260325_213907',
#  'pasta_ingestao': 'c:\\GIT\\DadosANS\\processamentos\\TR_20260325_213907\\ingestao',
#  'manifesto_arquivos': 'c:\\GIT\\DadosANS\\processamentos\\TR_20260325_213907\\manifesto_arquivos.csv',
#  'arquivos_lidos': ['pda-048-taxa_de_resolutividade.csv'],
#  'arquivos_ignorados': [],
#  'erros': [],
#  'df_unificado': None}

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

PPH - Produtos e Prestadores Hospitalares:
    
Trata-se de conjunto de dados abertos que contém informações sobre a Rede de atendimento hospitalar ou urgência/emergência por plano de saúde: 
Listagem da rede de atendimento hospitalar ou urgência/emergência por plano de saúde e operadora.

_____________________________________________________________________________________________________________________________________________________________________________________________________
    
Fluxo:

1. Gera o arquivo com a função ut.baixar_extrair_mesclar()
2. Lê o arquivo com a função read_csv() fornecida na saída da função.

O arquivo final (mesclado) contém 36MB
"""

pph_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/produtos_e_prestadores_hospitalares/produtos_e_prestadores_hospitalares.zip'
ut.baixar_extrair_mesclar(pph_url)

#df_mescla_hospitalares = pl.read_csv(r"c:\GIT\DadosANS\mescla_HOSPITALARES.csv")
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : inicialização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Início do processamento
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/produtos_e_prestadores_hospitalares/produtos_e_prestadores_hospitalares.zip
# 📄 ARQUIVO: produtos_e_prestadores_hospitalares.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_origem
# 🧭 ETAPA : Origem detectada: arquivo_zip
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/produtos_e_prestadores_hospitalares/produtos_e_prestadores_hospitalares.zip
# 📄 ARQUIVO: produtos_e_prestadores_hospitalares.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: https://dadosabertos.ans.gov.br/FTP/PDA/produtos_e_prestadores_hospitalares/produtos_e_prestadores_hospitalares.zip
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220
# 📄 ARQUIVO: 1 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🌐 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : Baixando arquivo único
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/produtos_e_prestadores_hospitalares/produtos_e_prestadores_hospitalares.zip
# 📄 ARQUIVO: produtos_e_prestadores_hospitalares.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_e_prestadores_hospitalares.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AC.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/27 (0.0%)
# ⏳ FALTAM : 27
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AL.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/27 (3.7%)
# ⏳ FALTAM : 26
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AM.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/27 (7.4%)
# ⏳ FALTAM : 25
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AP.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/27 (11.1%)
# ⏳ FALTAM : 24
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_BA.csv
# 📊 STATUS : [████░░░░░░░░░░░░░░░░░░░░░░] 4/27 (14.8%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_CE.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 5/27 (18.5%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_DF.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 6/27 (22.2%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_ES.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 7/27 (25.9%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_GO.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 8/27 (29.6%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MA.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 9/27 (33.3%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MG.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 10/27 (37.0%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MS.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 11/27 (40.7%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MT.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 12/27 (44.4%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PA.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 13/27 (48.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PB.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 14/27 (51.9%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PE.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 15/27 (55.6%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PI.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 16/27 (59.3%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PR.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 17/27 (63.0%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RJ.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 18/27 (66.7%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RN.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 19/27 (70.4%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RO.csv
# 📊 STATUS : [███████████████████░░░░░░░] 20/27 (74.1%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RR.csv
# 📊 STATUS : [████████████████████░░░░░░] 21/27 (77.8%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RS.csv
# 📊 STATUS : [█████████████████████░░░░░] 22/27 (81.5%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SC.csv
# 📊 STATUS : [██████████████████████░░░░] 23/27 (85.2%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SE.csv
# 📊 STATUS : [███████████████████████░░░] 24/27 (88.9%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SP.csv
# 📊 STATUS : [████████████████████████░░] 25/27 (92.6%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: produtos_prestadores_hospitalares_TO.csv
# 📊 STATUS : [█████████████████████████░] 26/27 (96.3%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_arquivo_unico
# 🧭 ETAPA : ZIP baixado e extraído recursivamente para disco
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\downloads\produtos_e_prestadores_hospitalares.zip
# 📄 ARQUIVO: produtos_e_prestadores_hospitalares.zip
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧮 FASE : planejamento
# 🔧 FUNÇÃO : definir_total_arquivos
# 🧭 ETAPA : Total de arquivos planejado: mesclagem incremental
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220
# 📄 ARQUIVO: 27 item(ns)
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/27 (0.0%)
# ⏳ FALTAM : 27
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AC.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/27 (0.0%)
# ⏳ FALTAM : 27
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AC.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/27 (3.7%)
# ⏳ FALTAM : 26
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AL.csv
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 1/27 (3.7%)
# ⏳ FALTAM : 26
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AL.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/27 (7.4%)
# ⏳ FALTAM : 25
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AM.csv
# 📊 STATUS : [██░░░░░░░░░░░░░░░░░░░░░░░░] 2/27 (7.4%)
# ⏳ FALTAM : 25
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AM.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/27 (11.1%)
# ⏳ FALTAM : 24
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_AP.csv
# 📊 STATUS : [███░░░░░░░░░░░░░░░░░░░░░░░] 3/27 (11.1%)
# ⏳ FALTAM : 24
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo HOSPITALARES
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_HOSPITALARES.csv
# 📊 STATUS : [████░░░░░░░░░░░░░░░░░░░░░░] 4/27 (14.8%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_BA.csv
# 📊 STATUS : [████░░░░░░░░░░░░░░░░░░░░░░] 4/27 (14.8%)
# ⏳ FALTAM : 23
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_BA.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 5/27 (18.5%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_CE.csv
# 📊 STATUS : [█████░░░░░░░░░░░░░░░░░░░░░] 5/27 (18.5%)
# ⏳ FALTAM : 22
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_CE.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 6/27 (22.2%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_DF.csv
# 📊 STATUS : [██████░░░░░░░░░░░░░░░░░░░░] 6/27 (22.2%)
# ⏳ FALTAM : 21
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_DF.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 7/27 (25.9%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_ES.csv
# 📊 STATUS : [███████░░░░░░░░░░░░░░░░░░░] 7/27 (25.9%)
# ⏳ FALTAM : 20
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_ES.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 8/27 (29.6%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_GO.csv
# 📊 STATUS : [████████░░░░░░░░░░░░░░░░░░] 8/27 (29.6%)
# ⏳ FALTAM : 19
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_GO.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 9/27 (33.3%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MA.csv
# 📊 STATUS : [█████████░░░░░░░░░░░░░░░░░] 9/27 (33.3%)
# ⏳ FALTAM : 18
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MA.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 10/27 (37.0%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MG.csv
# 📊 STATUS : [██████████░░░░░░░░░░░░░░░░] 10/27 (37.0%)
# ⏳ FALTAM : 17
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MG.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 11/27 (40.7%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MS.csv
# 📊 STATUS : [███████████░░░░░░░░░░░░░░░] 11/27 (40.7%)
# ⏳ FALTAM : 16
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MS.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 12/27 (44.4%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MT.csv
# 📊 STATUS : [████████████░░░░░░░░░░░░░░] 12/27 (44.4%)
# ⏳ FALTAM : 15
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_MT.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 13/27 (48.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PA.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 13/27 (48.1%)
# ⏳ FALTAM : 14
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PA.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 14/27 (51.9%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PB.csv
# 📊 STATUS : [█████████████░░░░░░░░░░░░░] 14/27 (51.9%)
# ⏳ FALTAM : 13
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PB.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 15/27 (55.6%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PE.csv
# 📊 STATUS : [██████████████░░░░░░░░░░░░] 15/27 (55.6%)
# ⏳ FALTAM : 12
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PE.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 16/27 (59.3%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PI.csv
# 📊 STATUS : [███████████████░░░░░░░░░░░] 16/27 (59.3%)
# ⏳ FALTAM : 11
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PI.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 17/27 (63.0%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PR.csv
# 📊 STATUS : [████████████████░░░░░░░░░░] 17/27 (63.0%)
# ⏳ FALTAM : 10
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_PR.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 18/27 (66.7%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RJ.csv
# 📊 STATUS : [█████████████████░░░░░░░░░] 18/27 (66.7%)
# ⏳ FALTAM : 9
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RJ.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 19/27 (70.4%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RN.csv
# 📊 STATUS : [██████████████████░░░░░░░░] 19/27 (70.4%)
# ⏳ FALTAM : 8
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RN.csv
# 📊 STATUS : [███████████████████░░░░░░░] 20/27 (74.1%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RO.csv
# 📊 STATUS : [███████████████████░░░░░░░] 20/27 (74.1%)
# ⏳ FALTAM : 7
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RO.csv
# 📊 STATUS : [████████████████████░░░░░░] 21/27 (77.8%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RR.csv
# 📊 STATUS : [████████████████████░░░░░░] 21/27 (77.8%)
# ⏳ FALTAM : 6
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Mesclagem concluída para o grupo HOSPITALARES
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: mescla_HOSPITALARES.csv
# 📊 STATUS : [█████████████████████░░░░░] 22/27 (81.5%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RS.csv
# 📊 STATUS : [█████████████████████░░░░░] 22/27 (81.5%)
# ⏳ FALTAM : 5
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_RS.csv
# 📊 STATUS : [██████████████████████░░░░] 23/27 (85.2%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SC.csv
# 📊 STATUS : [██████████████████████░░░░] 23/27 (85.2%)
# ⏳ FALTAM : 4
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SC.csv
# 📊 STATUS : [███████████████████████░░░] 24/27 (88.9%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SE.csv
# 📊 STATUS : [███████████████████████░░░] 24/27 (88.9%)
# ⏳ FALTAM : 3
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SE.csv
# 📊 STATUS : [████████████████████████░░] 25/27 (92.6%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SP.csv
# 📊 STATUS : [████████████████████████░░] 25/27 (92.6%)
# ⏳ FALTAM : 2
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_SP.csv
# 📊 STATUS : [█████████████████████████░] 26/27 (96.3%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🧩 FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Processando arquivo ingerido
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_TO.csv
# 📊 STATUS : [█████████████████████████░] 26/27 (96.3%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ❌ FASE : mesclagem
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Erro ao mesclar arquivo
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares
# 📄 ARQUIVO: produtos_prestadores_hospitalares_TO.csv
# 📊 STATUS : [██████████████████████████] 27/27 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 💾 FASE : saída
# 🔧 FUNÇÃO : mesclar_arquivos_ingeridos
# 🧭 ETAPA : Arquivos CSV por grupo gerados com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS
# 📄 ARQUIVO: 1 grupo(s)
# 📊 STATUS : [██████████████████████████] 1/1 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📌 COMANDOS PRONTOS PARA LEITURA DOS ARQUIVOS NO POLARS
# Cole os comandos abaixo no notebook:
#
# import polars as pl
#
# # Arquivos originais baixados/gerados
# df_origem_produtos_prestadores_hospitalares_ac = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_AC.csv")
# df_origem_produtos_prestadores_hospitalares_al = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_AL.csv")
# df_origem_produtos_prestadores_hospitalares_am = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_AM.csv")
# df_origem_produtos_prestadores_hospitalares_ap = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_AP.csv")
# df_origem_produtos_prestadores_hospitalares_ba = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_BA.csv")
# df_origem_produtos_prestadores_hospitalares_ce = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_CE.csv")
# df_origem_produtos_prestadores_hospitalares_df = pl.read_csv(r"c:\GIT\DadosANS\processamentos\PPH_20260325_214220\ingestao\extraidos\produtos_e_prestadores_hospitalares\produtos_prestadores_hospitalares_DF.csv")
# ...
# # Arquivos mesclados por grupo
# df_mescla_hospitalares = pl.read_csv(r"c:\GIT\DadosANS\mescla_HOSPITALARES.csv")
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🏁 FASE : finalização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Processamento concluído com sucesso
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\PPH_20260325_214220
# 📄 ARQUIVO: resultado final
# 📊 STATUS : [██████████████████████████] 27/27 (100.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# {'conteudo_zip': None,
#  'pasta_execucao': 'c:\\GIT\\DadosANS\\processamentos\\PPH_20260325_214220',
#  'pasta_ingestao': 'c:\\GIT\\DadosANS\\processamentos\\PPH_20260325_214220\\ingestao',
#  'manifesto_arquivos': 'c:\\GIT\\DadosANS\\processamentos\\PPH_20260325_214220\\manifesto_arquivos.csv',
#  'arquivos_lidos': ['produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_AP.csv',
#   'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_RR.csv'],
#  'arquivos_ignorados': [],
#  'erros': [{'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_AC.csv',
#    'erro': 'Falha na mesclagem incremental: file encoding is not UTF-8'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_AL.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"0630000000171-1"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 49195 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"0630000000171-1"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_AM.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"7601 ao 7612/S"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 126 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"7601 ao 7612/S"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_BA.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878040P040"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 52227 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878040P040"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_CE.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"XX 6001"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 7545 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"XX 6001"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_DF.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"T00155"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 6861 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"T00155"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_ES.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"0700G"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 3378 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"0700G"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_GO.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878046P046"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 61756 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878046P046"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_MA.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"P0024"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 9994 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"P0024"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_MG.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"00205-012"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 9724 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"00205-012"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_MS.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"9999990005N"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 119398 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"9999990005N"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_MT.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"0703F"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 3751 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"0703F"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_PA.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"0108-0166"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 13215 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"0108-0166"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_PB.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"2-4-23-B+3"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 397337 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"2-4-23-B+3"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_PE.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"T00141701"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 41952 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"T00141701"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_PI.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"9999999208N"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 118 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"9999999208N"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_PR.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878026P026"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 3378 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878026P026"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_RJ.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878062P062"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 18390 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878062P062"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_RN.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"0630000000172-1"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 14977 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"0630000000172-1"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_RO.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"T00180"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 23727 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"T00180"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_RS.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878051P051"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 5449 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878051P051"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_SC.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"878026P026"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 2152 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"878026P026"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_SE.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"UPJV1234"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 95563 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"UPJV1234"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_SP.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"CLUBE-027"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 29641 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"CLUBE-027"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'},
#   {'arquivo': 'produtos_e_prestadores_hospitalares.zip::produtos_prestadores_hospitalares_TO.csv',
#    'erro': 'Falha na mesclagem incremental: could not parse `"P123"` as dtype `i64` at column \'CD_PLANO\' (column number 7)\n\nThe current offset in the file is 9523 bytes.\n\nYou might want to try:\n- increasing `infer_schema_length` (e.g. `infer_schema_length=10000`),\n- specifying correct dtype with the `schema_overrides` argument\n- setting `ignore_errors` to `True`,\n- adding `"P123"` to the `null_values` list.\n\nOriginal error: ```invalid primitive value found during CSV parsing```'}],
#  'df_unificado': None}

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

RPC - Dados_Comunicados de Reajustes de Planos em Contratos Coletivos:

O banco de dados dos comunicados de reajuste dos contratos coletivos (RPC) é alimentado constantemente pelas operadoras mediante a aplicação dos reajustes de seus contratos e dentro dos prazos determinados,
conforme a norma em vigor. A IN/DIPRO nº 13, de 21 de julho de 2006, trata dos procedimentos de comunicação dos reajustes de planos coletivos à ANS e determina os prazos para envio destes comunicados, 
definindo os trimestres de envio como ocorrendo de: (1) março a maio, (2) junho a agosto, (3) setembro a novembro e (4) dezembro a fevereiro O prazo limite para envio dos comunicados de cada trimestre é o último dia do mês seguinte à conclusão do trimestre.

_____________________________________________________________________________________________________________________________________________________________________________________________________

rpc_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/RPC/'
rpc_resultado = ut.baixar_extrair_juntar(rpc_url)
rpc_df = rpc_resultado['df_unificado']
rpc_df.to_csv('reajuste_contratos_coletivos.csv') # Gera um .csv com o arquivo mesclado na mesma pasta deste notebook

"""

rpc_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/RPC/'
ut.baixar_extrair_mesclar(rpc_url)
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201505_AMB_CONS
# 📄 ARQUIVO: ES_201505_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 244/17145 (1.4%)
# ⏳ FALTAM : 16901
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201505_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201505_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 245/17145 (1.4%)
# ⏳ FALTAM : 16900
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201505_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 245/17145 (1.4%)
# ⏳ FALTAM : 16900
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201505_AMB_DET
# 📄 ARQUIVO: ES_201505_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 245/17145 (1.4%)
# ⏳ FALTAM : 16900
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201505_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201505_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 246/17145 (1.4%)
# ⏳ FALTAM : 16899
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201506_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 246/17145 (1.4%)
# ⏳ FALTAM : 16899
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201506_AMB_CONS
# 📄 ARQUIVO: ES_201506_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 246/17145 (1.4%)
# ⏳ FALTAM : 16899
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201506_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201506_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 247/17145 (1.4%)
# ⏳ FALTAM : 16898
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201506_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 247/17145 (1.4%)
# ⏳ FALTAM : 16898
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201506_AMB_DET
# 📄 ARQUIVO: ES_201506_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 247/17145 (1.4%)
# ⏳ FALTAM : 16898
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201506_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201506_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 248/17145 (1.4%)
# ⏳ FALTAM : 16897
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201507_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 248/17145 (1.4%)
# ⏳ FALTAM : 16897
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201507_AMB_CONS
# 📄 ARQUIVO: ES_201507_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 248/17145 (1.4%)
# ⏳ FALTAM : 16897
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201507_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201507_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 249/17145 (1.5%)
# ⏳ FALTAM : 16896
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201507_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 249/17145 (1.5%)
# ⏳ FALTAM : 16896
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201507_AMB_DET
# 📄 ARQUIVO: ES_201507_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 249/17145 (1.5%)
# ⏳ FALTAM : 16896
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201507_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201507_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 250/17145 (1.5%)
# ⏳ FALTAM : 16895
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201508_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 250/17145 (1.5%)
# ⏳ FALTAM : 16895
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201508_AMB_CONS
# 📄 ARQUIVO: ES_201508_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 250/17145 (1.5%)
# ⏳ FALTAM : 16895
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201508_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201508_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 251/17145 (1.5%)
# ⏳ FALTAM : 16894
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201508_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 251/17145 (1.5%)
# ⏳ FALTAM : 16894
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201508_AMB_DET
# 📄 ARQUIVO: ES_201508_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 251/17145 (1.5%)
# ⏳ FALTAM : 16894
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201508_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201508_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 252/17145 (1.5%)
# ⏳ FALTAM : 16893
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201509_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 252/17145 (1.5%)
# ⏳ FALTAM : 16893
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201509_AMB_CONS
# 📄 ARQUIVO: ES_201509_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 252/17145 (1.5%)
# ⏳ FALTAM : 16893
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201509_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201509_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 253/17145 (1.5%)
# ⏳ FALTAM : 16892
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201509_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 253/17145 (1.5%)
# ⏳ FALTAM : 16892
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201509_AMB_DET
# 📄 ARQUIVO: ES_201509_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 253/17145 (1.5%)
# ⏳ FALTAM : 16892
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201509_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201509_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 254/17145 (1.5%)
# ⏳ FALTAM : 16891
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201510_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 254/17145 (1.5%)
# ⏳ FALTAM : 16891
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201510_AMB_CONS
# 📄 ARQUIVO: ES_201510_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 254/17145 (1.5%)
# ⏳ FALTAM : 16891
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201510_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201510_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 255/17145 (1.5%)
# ⏳ FALTAM : 16890
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201510_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 255/17145 (1.5%)
# ⏳ FALTAM : 16890
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201510_AMB_DET
# 📄 ARQUIVO: ES_201510_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 255/17145 (1.5%)
# ⏳ FALTAM : 16890
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201510_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201510_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 256/17145 (1.5%)
# ⏳ FALTAM : 16889
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201511_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 256/17145 (1.5%)
# ⏳ FALTAM : 16889
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201511_AMB_CONS
# 📄 ARQUIVO: ES_201511_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 256/17145 (1.5%)
# ⏳ FALTAM : 16889
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201511_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201511_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 257/17145 (1.5%)
# ⏳ FALTAM : 16888
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201511_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 257/17145 (1.5%)
# ⏳ FALTAM : 16888
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201511_AMB_DET
# 📄 ARQUIVO: ES_201511_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 257/17145 (1.5%)
# ⏳ FALTAM : 16888
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201511_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201511_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 258/17145 (1.5%)
# ⏳ FALTAM : 16887
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201512_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 258/17145 (1.5%)
# ⏳ FALTAM : 16887
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201512_AMB_CONS
# 📄 ARQUIVO: ES_201512_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 258/17145 (1.5%)
# ⏳ FALTAM : 16887
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201512_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201512_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 259/17145 (1.5%)
# ⏳ FALTAM : 16886
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201512_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 259/17145 (1.5%)
# ⏳ FALTAM : 16886
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\ES_201512_AMB_DET
# 📄 ARQUIVO: ES_201512_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 259/17145 (1.5%)
# ⏳ FALTAM : 16886
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: ES_201512_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: ES_201512_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 260/17145 (1.5%)
# ⏳ FALTAM : 16885
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201501_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 260/17145 (1.5%)
# ⏳ FALTAM : 16885
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201501_AMB_CONS
# 📄 ARQUIVO: GO_201501_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 260/17145 (1.5%)
# ⏳ FALTAM : 16885
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201501_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201501_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 261/17145 (1.5%)
# ⏳ FALTAM : 16884
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201501_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 261/17145 (1.5%)
# ⏳ FALTAM : 16884
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201501_AMB_DET
# 📄 ARQUIVO: GO_201501_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 261/17145 (1.5%)
# ⏳ FALTAM : 16884
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201501_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201501_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 262/17145 (1.5%)
# ⏳ FALTAM : 16883
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201502_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 262/17145 (1.5%)
# ⏳ FALTAM : 16883
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201502_AMB_CONS
# 📄 ARQUIVO: GO_201502_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 262/17145 (1.5%)
# ⏳ FALTAM : 16883
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201502_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201502_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 263/17145 (1.5%)
# ⏳ FALTAM : 16882
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201502_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 263/17145 (1.5%)
# ⏳ FALTAM : 16882
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201502_AMB_DET
# 📄 ARQUIVO: GO_201502_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 263/17145 (1.5%)
# ⏳ FALTAM : 16882
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201502_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201502_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 264/17145 (1.5%)
# ⏳ FALTAM : 16881
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201503_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 264/17145 (1.5%)
# ⏳ FALTAM : 16881
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201503_AMB_CONS
# 📄 ARQUIVO: GO_201503_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 264/17145 (1.5%)
# ⏳ FALTAM : 16881
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201503_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201503_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 265/17145 (1.5%)
# ⏳ FALTAM : 16880
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201503_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 265/17145 (1.5%)
# ⏳ FALTAM : 16880
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201503_AMB_DET
# 📄 ARQUIVO: GO_201503_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 265/17145 (1.5%)
# ⏳ FALTAM : 16880
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201503_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201503_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 266/17145 (1.6%)
# ⏳ FALTAM : 16879
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201504_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 266/17145 (1.6%)
# ⏳ FALTAM : 16879
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201504_AMB_CONS
# 📄 ARQUIVO: GO_201504_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 266/17145 (1.6%)
# ⏳ FALTAM : 16879
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201504_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201504_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 267/17145 (1.6%)
# ⏳ FALTAM : 16878
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201504_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 267/17145 (1.6%)
# ⏳ FALTAM : 16878
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201504_AMB_DET
# 📄 ARQUIVO: GO_201504_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 267/17145 (1.6%)
# ⏳ FALTAM : 16878
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201504_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201504_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 268/17145 (1.6%)
# ⏳ FALTAM : 16877
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201505_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 268/17145 (1.6%)
# ⏳ FALTAM : 16877
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\GO_201505_AMB_CONS
# 📄 ARQUIVO: GO_201505_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 268/17145 (1.6%)
# ⏳ FALTAM : 16877
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201505_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: GO_201505_AMB_CONS.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 269/17145 (1.6%)
# ⏳ FALTAM : 16876
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: GO_201505_AMB_DET.zip
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 269/17145 (1.6%)
# ⏳ FALTAM : 16876
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ...
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201510_AMB_CONS
# 📄 ARQUIVO: SE_201510_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 662/17145 (3.9%)
# ⏳ FALTAM : 16483
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201510_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201510_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 663/17145 (3.9%)
# ⏳ FALTAM : 16482
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201510_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 663/17145 (3.9%)
# ⏳ FALTAM : 16482
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201510_AMB_DET
# 📄 ARQUIVO: SE_201510_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 663/17145 (3.9%)
# ⏳ FALTAM : 16482
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201510_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201510_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 664/17145 (3.9%)
# ⏳ FALTAM : 16481
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201511_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 664/17145 (3.9%)
# ⏳ FALTAM : 16481
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201511_AMB_CONS
# 📄 ARQUIVO: SE_201511_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 664/17145 (3.9%)
# ⏳ FALTAM : 16481
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201511_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201511_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 665/17145 (3.9%)
# ⏳ FALTAM : 16480
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201511_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 665/17145 (3.9%)
# ⏳ FALTAM : 16480
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201511_AMB_DET
# 📄 ARQUIVO: SE_201511_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 665/17145 (3.9%)
# ⏳ FALTAM : 16480
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201511_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201511_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 666/17145 (3.9%)
# ⏳ FALTAM : 16479
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201512_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 666/17145 (3.9%)
# ⏳ FALTAM : 16479
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201512_AMB_CONS
# 📄 ARQUIVO: SE_201512_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 666/17145 (3.9%)
# ⏳ FALTAM : 16479
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201512_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=CONS)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201512_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 667/17145 (3.9%)
# ⏳ FALTAM : 16478
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201512_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 667/17145 (3.9%)
# ⏳ FALTAM : 16478
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SE_201512_AMB_DET
# 📄 ARQUIVO: SE_201512_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 667/17145 (3.9%)
# ⏳ FALTAM : 16478
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SE_201512_AMB_DET.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ✅ FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : ZIP baixado e extraído recursivamente (grupo=DET)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\downloads
# 📄 ARQUIVO: SE_201512_AMB_DET.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 668/17145 (3.9%)
# ⏳ FALTAM : 16477
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📡 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_listagem_remota
# 🧭 ETAPA : Processando item da estrutura remota
# 📂 CAMINHO: .
# 📄 ARQUIVO: SP_201501_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 668/17145 (3.9%)
# ⏳ FALTAM : 16477
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🗜️ FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Extraindo ZIP (nível 0)
# 📂 CAMINHO: c:\GIT\DadosANS\processamentos\RPC_20260325_220451\ingestao\extraidos\SP_201501_AMB_CONS
# 📄 ARQUIVO: SP_201501_AMB_CONS.zip
# 📊 STATUS : [█░░░░░░░░░░░░░░░░░░░░░░░░░] 668/17145 (3.9%)
# ⏳ FALTAM : 16477
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 📦 FASE : ingestão
# 🔧 FUNÇÃO : extrair_zip_recursivamente
# 🧭 ETAPA : Processando item interno do ZIP (nível 0)
# 📂 CAMINHO: .
# 📄 ARQUIVO: SP_201501_AMB_CONS.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/1 (0.0%)
# ⏳ FALTAM : 1
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 20
#       1 """
#       2 _____________________________________________________________________________________________________________________________________________________________________________________________________
#       3
#    (...)     16
#      17 """
#      19 rpc_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/RPC/'
# ---> 20 ut.baixar_extrair_mesclar(rpc_url)
#
# File c:\GIT\DadosANS\utils.py:1335, in baixar_extrair_mesclar(url_origem, nome_pasta_execucao, base_dir_execucao, pasta_saida_mesclas, chunk_size_csv, retornar_df_unificado, reter_conteudo_zip_em_memoria, profundidade_maxima_zip)
#    1322     return pl.concat(dfs_finais, how="diagonal_relaxed")
#    1324 imprimir_log(
#    1325     fase="inicialização",
#    1326     funcao="baixar_extrair_mesclar",
#    (...)   1332     icone="🚀",
#    1333 )
# -> 1335 ingerir_origem()
#    1336 df_unificado: Optional[pl.DataFrame] = mesclar_arquivos_ingeridos()
#    1338 conteudo_zip: Optional[bytes] = None
#
# File c:\GIT\DadosANS\utils.py:1083, in baixar_extrair_mesclar.<locals>.ingerir_origem()
#    1081 arquivos_descobertos = listar_arquivos_http(url_origem)
#    1082 definir_total_arquivos(len(arquivos_descobertos), url_origem)
# -> 1083 ingerir_listagem_remota(arquivos_descobertos)
#    1084 return
#
# File c:\GIT\DadosANS\utils.py:979, in baixar_extrair_mesclar.<locals>.ingerir_listagem_remota(arquivos_descobertos)
#     977 if extensao == ".zip":
#     978     grupo_zip: str = obter_grupo_mescla(nome_arquivo)
# --> 979     extrair_zip_recursivamente(
#     980         caminho_zip=destino_download,
#     981         origem_url=url_arquivo,
#     982         grupo_mescla_padrao=grupo_zip,
#     983         prefixo_origem_zip=None,
#     984         profundidade_atual=0,
#     985     )
#     986     atualizar_progresso_global(
#     987         fase="ingestão",
#     988         funcao="ingerir_listagem_remota",
#    (...)    992         icone="✅",
#     993     )
#     994     continue
#
# File c:\GIT\DadosANS\utils.py:794, in baixar_extrair_mesclar.<locals>.extrair_zip_recursivamente(caminho_zip, origem_url, grupo_mescla_padrao, prefixo_origem_zip, profundidade_atual)
#     792 try:
#     793     with arquivo_zip.open(info) as origem, destino_item.open("wb") as destino:
# --> 794         shutil.copyfileobj(origem, destino)
#     796     if extensao_item == ".zip":
#     797         grupo_zip_interno: str = grupo_mescla_padrao or obter_grupo_mescla(nome_item)
#
# File c:\Program Files\Python313\Lib\shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File c:\Program Files\Python313\Lib\zipfile\__init__.py:1015, in ZipExtFile.read(self, n)
#    1013 self._offset = 0
#    1014 while n > 0 and not self._eof:
# -> 1015     data = self._read1(n)
#    1016     if n < len(data):
#    1017         self._readbuffer = data
#
# File c:\Program Files\Python313\Lib\zipfile\__init__.py:1091, in ZipExtFile._read1(self, n)
#    1089 elif self._compress_type == ZIP_DEFLATED:
#    1090     n = max(n, self.MIN_READ_SIZE)
# -> 1091     data = self._decompressor.decompress(data, n)
#    1092     self._eof = (self._decompressor.eof or
#    1093                  self._compress_left <= 0 and
#    1094                  not self._decompressor.unconsumed_tail)
#    1095     if self._eof:
#
# KeyboardInterrupt:

# %%
"""
_____________________________________________________________________________________________________________________________________________________________________________________________________

PHR - Procedimentos Hospitalares Realizados

Trata-se de um conjunto de dados abertos contendo uma Lista de procedimentos realizados em ambiente hospitalar pelos estabelecimentos que prestam serviço às operadoras de planos de saúde, 
por UF e mês e ano de competência.
_____________________________________________________________________________________________________________________________________________________________________________________________________

Este dataset é formado por inumeras pastas e arquivos, as quais ao final do processamento da função terão dezenas de milhões de registros, em razão disso, a função pode levar muitas horas para completar o processamento.

Dessa forma, orienta-se a utilização da versão "Big Data" da solução, a qual poderá ser executada em um ambiente Databricks.

# Baixa, extrai, junta e gera arquivos com os dfs (processamento demorado); 

phr_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/TISS/HOSPITALAR/'
phr_resultado = ut.baixar_extrair_juntar(phr_url)

"""
# Baixa os arquivos com os dicionários de termos utilizados no df

ut.baixar_arquivo(
    'https://dadosabertos.ans.gov.br/FTP/PDA/TISS/DICIONARIO/Dicionario_de_variaveis_a_partir_de_2023.ods')
ut.baixar_arquivo(
    'https://dadosabertos.ans.gov.br/FTP/PDA/TISS/DICIONARIO/Dicionario_de_variaveis_ate_2022.ods')
