# %%
from utils_teste import baixar_extrair_mesclar
import polars as pl
import pandas as pd

# %%
igr_url = 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv'

baixar_extrair_mesclar(igr_url, retornar_lazyframe_unificado=True, colunas=['REGISTRO_ANS', 'RAZAO_SOCIAL', 'COBERTURA', 'IGR', 'QTD_RECLAMACOES'])
# Out:
# \n════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : inicialização
# 🔧 FUNÇÃO : baixar_extrair_mesclar
# 🧭 ETAPA : Início do processamento
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# \n════════════════════════════════════════════════════════════════════════════════════════════════════════════
# 🚀 FASE : ingestão
# 🔧 FUNÇÃO : ingerir_origem
# 🧭 ETAPA : Origem detectada: arquivo_tabular
# 📂 CAMINHO: https://dadosabertos.ans.gov.br/FTP/PDA/IGR/IGR_versao_2023/IGR.csv
# 📄 ARQUIVO: IGR.csv
# 📊 STATUS : [░░░░░░░░░░░░░░░░░░░░░░░░░░] 0/0 (0.0%)
# ⏳ FALTAM : 0
# ════════════════════════════════════════════════════════════════════════════════════════════════════════════
# ...

# %%
lf_origem_igr = pl.scan_parquet(r"c:\GIT\DadosANS\processamentos\igr_parquet_7_20260509_192130\ingestao\downloads\IGR.parquet")

# %%
lf_origem_igr.head()
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>SLICE[offset: 0, len: 5]<p></p>  Parquet SCAN [c:/GIT/DadosANS/processamentos/igr_parquet_7_20260509_192130/ingestao/downloads/IGR.parquet]<p></p>  PROJECT */5 COLUMNS<p></p>  ESTIMATED ROWS: 149519</div>
